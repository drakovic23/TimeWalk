# %%
import timewalk as tw
import matplotlib.pyplot as plt
from timewalk.strategy_classes import *

bt = tw.BackTester()

result = (bt.load_data("SPY", "1h").run(RsiStrategy(rsi_window=20, oversold_threshold=70, overbought_threshold=30, atr_window=20)))

result.tail()
# Out:
# Running backtest with:  RSI Strategy  Using ATR:  True
#                           Signal  RealizedPnL  UnrealizedPnL  TotalRealPnL  \
# Datetime
# 2025-01-22 11:30:00-05:00   None          0.0     -16.600342    674.192505
# 2025-01-22 12:30:00-05:00   None          0.0      -6.926270    674.192505
# 2025-01-22 13:30:00-05:00   None          0.0      -3.701172    674.192505
# 2025-01-22 14:30:00-05:00   None          0.0      -8.000488    674.192505
# 2025-01-22 15:30:00-05:00   None          0.0       7.598877    674.192505
#
#                            CurrentCapital  Position  EntryPrice  ClosingPrice
# Datetime
# 2025-01-22 11:30:00-05:00     9530.507812         0         0.0    607.549988
# 2025-01-22 12:30:00-05:00     9540.181885         0         0.0    607.066284
# 2025-01-22 13:30:00-05:00     9543.406982         0         0.0    606.905029
# 2025-01-22 14:30:00-05:00     9539.107666         0         0.0    607.119995
# 2025-01-22 15:30:00-05:00     9554.707031         0         0.0    606.340027

# %%
plt.figure(figsize=(10,6))
plt.plot(result.index, result['TotalRealPnL'], label='TotalRealPnL', linewidth=2)
plt.plot(result.index, result['CurrentCapital'], label='CurrentCapital', linewidth=2)
plt.xlabel('DateTime')
plt.ylabel('TotalRealPnL')
plt.title('Total Realized P&L Over Time')
plt.legend()
plt.grid(True)

plt.show()
